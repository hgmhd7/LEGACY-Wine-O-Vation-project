# %%
# Import pandas
import pandas as pd

# %%
master_df = pd.read_csv('../../data/recommender_table.csv')

# %%
master_df.head()
# Out:
#                                                title   country    province  \
# 0  Tenuta dell'Ornellaia 2007 Masseto Merlot (Tos...     Italy     Tuscany
# 1      Casa Ferreirinha 2008 Barca-Velha Red (Douro)  Portugal       Douro
# 2  Biondi Santi 2010 Riserva  (Brunello di Montal...     Italy     Tuscany
# 3    Cardinale 2006 Cabernet Sauvignon (Napa Valley)        US  California
# 4         Château Léoville Barton 2010  Saint-Julien    France    Bordeaux
#
#                     winery  price  points                   variety category  \
# 0    Tenuta dell'Ornellaia    460     100                    Merlot      red
# 1         Casa Ferreirinha    450     100            Portuguese Red      red
# 2             Biondi Santi    550     100                Sangiovese      red
# 3                Cardinale    200     100        Cabernet Sauvignon      red
# 4  Château Léoville Barton    150     100  Bordeaux-style Red Blend      red
#
#               flavor_notes                                        description
# 0  medium bodied, balanced  A perfect wine from a classic vintage, the 200...
# 1  medium bodied, balanced  This is the latest release of what has long be...
# 2  medium bodied, balanced  This gorgeous, fragrant wine opens with classi...
# 3  medium bodied, balanced  Tasted in a flight of great and famous Napa wi...
# 4                    other  This is a magnificently solid wine, initially ...

# %%
export = master_df.to_json("../../wine_application/parallax-template/static/js/recommender_json.json", orient='records')
