# %%
import pandas as pd
import numpy as np
import pyreadstat
import os

# %%
df, meta = pyreadstat.read_sav("Inequality_GINI_Dissertation_Stacked_Final_copy.sav")

# %%
df.head(20)
# Out:
#    Census_Year  GEO_FIPS                            METAREA         Race  \
# 0         1990   10420.0                          Akron, OH  All OtherNH
# 1         1990   10420.0                          Akron, OH     Asian NH
# 2         1990   10420.0                          Akron, OH     Black NH
# 3         1990   10420.0                          Akron, OH     Hispanic
# 4         1990   10420.0                          Akron, OH     White NH
# 5         1990   10420.0                          Akron, OH        Total
# 6         1990   10580.0        Albany-Schenectady-Troy, NY  All OtherNH
# 7         1990   10580.0        Albany-Schenectady-Troy, NY     Asian NH
# 8         1990   10580.0        Albany-Schenectady-Troy, NY     Black NH
# 9         1990   10580.0        Albany-Schenectady-Troy, NY     Hispanic
# 10        1990   10580.0        Albany-Schenectady-Troy, NY     White NH
# 11        1990   10580.0        Albany-Schenectady-Troy, NY        Total
# ...
